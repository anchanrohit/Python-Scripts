# %%
import pandas as pd

# %%
import os 
cwd=os.getcwd()

# %%
print(cwd)
# Out:
# /Users/rohitanchan

# %%
path=cwd+'/Desktop/DataSets/Netflix Dataset.csv'

# %%
data=pd.read_csv(path)

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %% [markdown]
# ## Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ## Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# year              10
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
data[data.Title == 'House of Cards'][["Show_Id", "Director"]]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# ## Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
data['year'] = data['Release_Date'].str[-4:]

# %%
data.groupby('year')['Show_Id'].count().sort_values()
# Out:
# year
# 2010       1
# 2008       2
# 2009       2
# 2012       3
# 2013      11
# 2011      13
# 2014      25
# 2015      88
# 2021     117
# 2016     443
# 2017    1225
# 2018    1685
# 2020    2009
# 2019    2153
# Name: Show_Id, dtype: int64

# %%
data.groupby('year')['Show_Id'].count().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ## Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
data.groupby('Category')['Show_Id'].count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Show_Id, dtype: int64

# %%
sns.countplot(data['Category'])
# Out:
# /Users/rohitanchan/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ## Q. 4) Show all the Movies that were released in year 2000.

# %%
data[(data['year']=='2020') & (data['Category']=='Movie')]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# ## Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
data[(data['Country']=='India') & (data['Category']=='TV Show')]["Title"]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ## Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
data.groupby('Director')['Show_Id'].count().sort_values().tail(10)
# Out:
# Director
# Hakan Algül                8
# David Dhawan               9
# Steven Spielberg          10
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Cathy Garcia-Molina       13
# Jay Karas                 14
# Marcus Raboy              16
# Raúl Campos, Jan Suter    18
# Name: Show_Id, dtype: int64

# %% [markdown]
# ## Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
data[((data['Category']=='Movie') & (data['Type']=='Comdedies')) | (data['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title           Director  \
# 19       s20    Movie                     '89                NaN
# 58       s59  TV Show             100% Hotter                NaN
# 82       s83    Movie     2036 Origin Unknown      Hasraf Dulull
# 85       s86  TV Show                21 Again                NaN
# 93       s94    Movie       27: Gone Too Soon  Simon Napier-Bell
# ...      ...      ...                     ...                ...
# 7670   s7669  TV Show  World War II in Colour                NaN
# 7671   s7670  TV Show  World's Busiest Cities                NaN
# 7688   s7687    Movie  XV: Beyond the Tryline   Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu        James Brown
# 7740   s7739  TV Show         Young Wallander                NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ## Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
data_new=data.dropna()

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description  year
# 3860  Through chance, human action, past history and...  2020
# 5071  A fast-talking yuppie is forced to slow down w...  2019

# %% [markdown]
# ## Q. 9) What are the different Ratings defined by Netflix ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description  year
# 0  In a future where the elite inhabit an island ...  2020
# 1  After a devastating earthquake hits Mexico Cit...  2016

# %%
data.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ## Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
data[(data.Rating =='TV-14') & (data.Category=='Movie') & (data.Country=='Canada')]['Show_Id'].count()
# Out:
# 11

# %% [markdown]
# ## Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
data[(data.Rating =='R') & (pd.to_numeric(data['year'])>2018) & (data['Category']=='TV Show')]['Show_Id'].count()
# Out:
# 1

# %% [markdown]
# ## Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
data[data.Category=='Movie'].sort_values(by=['Duration'],ascending=False).head(1)
# Out:
#      Show_Id Category         Title      Director  \
# 3292   s3293    Movie  Kaleidoscope  Rupert Jones
#
#                                                    Cast         Country  \
# 3292  Toby Jones, Anne Reid, Sinead Matthews, Cecili...  United Kingdom
#
#      Release_Date Rating Duration       Type  \
# 3292  May 8, 2018  TV-MA   99 min  Thrillers
#
#                                             Description  year
# 3292  A quiet ex-con's tenuous grip on reality start...  2018

# %% [markdown]
# ## Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
data[data['Category']=='TV Show'].groupby('Country')['Show_Id'].count().sort_values().tail(1)
# Out:
# Country
# United States    705
# Name: Show_Id, dtype: int64

# %% [markdown]
# ## Q. 12) How can we sort the dataset by Year ?

# %%
data.sort_values(by=['year'],ascending= True)
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %% [markdown]
# ## Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
data[(data.Category =='Movie') & (data.Type.str.match('Drama')) | (data.Category =='TV Show') & (data.Type.str.match('Kid'))]
# Out:
#      Show_Id Category        Title           Director  \
# 1         s2    Movie        07:19  Jorge Michel Grau
# 4         s5    Movie           21     Robert Luketic
# 7         s8    Movie          187     Kevin Reynolds
# 10       s11    Movie         1922       Zak Hilditch
# 15       s16    Movie       Oct-01     Kunle Afolayan
# ...      ...      ...          ...                ...
# 7772   s7771    Movie      Zinzana    Majid Al Ansari
# 7779   s7778  TV Show  Zombie Dumb                NaN
# 7782   s7781    Movie          Zoo       Shlok Sharma
# 7784   s7783    Movie         Zozo        Josef Fares
# 7785   s7784    Movie       Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# ...
